# %% [markdown]
# # How Transformers work in deep learning and NLP

# %% [markdown]
# [How Transformers work in deep learning and NLP - An Intuitive Intro](https://theaisummer.com/transformer/)
#
# by Nikolas Adaloglouon 2020-12-23, AI Summer School
#
# commented by Ivan Lin @
# <center>
# <img src="https://theaisummer.com/static/6122618d7e1466853e88473ba375cdc7/40ffe/transformer.png" width=800>
# </center>
