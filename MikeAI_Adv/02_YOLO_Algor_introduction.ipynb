# %% [markdown]
# <a href="https://colab.research.google.com/github/lin3372/250_ML.tutorial/blob/main/MikeAI_DL-Adv/02_YOLO_Algor_introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1 align='center' style='color:purple'> 課程 02 - An introduction to YOLO Algorithm - Multi Object Detection － Step By Step
#
# YOLO 演算法 介紹 - Python Tutorial</h1>

# %% [markdown]
# [課程 02 - An introduction to YOLO Algor - Multi Object Detection － Step By Step](https://interactiveuandmetutorialsac.weebly.com/3550631243-02---20154240372623424935-36914385423550631243---an-introduction-to-yolo-algorithm---yolo-284363163927861.html)
#
# [Youtube tutorial](https://youtu.be/53MfDaj1ZI4)
#
# Ivan H.P. Lin -

# %% [markdown]
# # YOLO Algorithm - Intro

# %% [markdown]
# ## YAD2K, Model conversion

# %% [markdown]
# 1. YAD2K - [YAD2K](https://github.com/allanzelener/YAD2K) (Yet Another Darknet 2 Keras) - YOLO_v2 Algor - Keras / Tensorflow
#   - https://github.com/allanzelener/YAD2K
#
# 2. DarkNet 網頁 - 鏈接 https://pjreddie.com/darknet/
#
# ===========================================================
# Model Conversion (模型轉換)
# 1. 從[YOLO官方網站](http://pjreddie.com/darknet/yolo/)下載 Darknet模型的 (config - cfg) 設置檔 與 (weights) 權重檔到 - 課程02 - 根目錄
#     - 例如:使用MS COCO資料集訓練的 - 預訓練模型
#       - 下載[YOLOv2 608x608 設置檔(yolo.cfg)](https://github.com/pjreddie/darknet/blob/master/cfg/yolo.cfg)
#       - 下載[YOLOv2 608x608 權重檔(yolo.weights)](https://pjreddie.com/media/files/yolo.weights)
#
# 2. 將使用 - Darknet 預訓練 的 - YOLO_v2 模型
#     - 透過 - yad2k.python - 命令 cmd 來 轉換為 - Keras 模型
#     -  Eg.: - python yad2k.py yolo2.cfg yolo2.weights model_data/yolov2_coco_608x608.h5
#             - yolov2_coco_608x608.h5
#             - yolov2_coco_608x608_anchors.txt

# %% [markdown]
# ## Directory structure for this example

# %% [markdown]
# 課程02 - Directory Structure 目錄結構
#
#       - 02 - YOLO Algor introduction.ipynb
#       - yad2k.py
#       - yolo2.cfg
#       - yolo2.weights
#       - ├── font/
#       - │   ├── FiraMono-Medium.otf
#       - │   └── SIL Open Font License.txt
#       - │
#       - ├── images/
#       - │   └── dog.jpg
#       - ├── yad2k/
#       - │   ├── __init__.py
#       - │   ├── models/
#       - │   ├── utils/
#       - │   └── __pycache__/
#       - └── model_data/
#       -     ├── coco_classes.txt
#       -     ├── pascal_classes.txt
#       -     ├── yolov2_coco_608x608.h5
#       -     └── yolov2_coco_608x608_anchors.txt

# %%
"""
課程02 - Directory Structure 目錄結構

02 - YOLO Algor introduction.ipynb
yad2k.py
yolo2.cfg
yolo2.weights
├── font/
│   ├── FiraMono-Medium.otf
│   └── SIL Open Font License.txt
│
├── images/
│   └── dog.jpg
├── yad2k/
│   ├── __init__.py
│   ├── models/
│   ├── utils/
│   └── __pycache__/
└── model_data/
    ├── coco_classes.txt
    ├── pascal_classes.txt
    ├── yolov2_coco_608x608.h5
    └── yolov2_coco_608x608_anchors.txt
"""

# %% [markdown]
# ## YOLO － You Only Look Once - 目標檢測  Object Detection
#   - [論文](https://pjreddie.com/media/files/papers/YOLOv3.pdf) 的網頁 - 鏈接 https://pjreddie.com/media/files/papers/YOLOv3.pdf. # YOLOv1/YOLOv2

# %% [markdown]
# YOLO 的優點
#  - 快速 - 適用於實時處理
#  - 預測（對象位置和類別）是從一個單一的網絡得出的
#     - 可以進行端到端的 培訓以提高 準確性
#  - YOLO 容易廣義的運用  - Generalized
#     - 從自然圖像推廣到其他領域（如藝術品）時，它的性能優於其他方法
#
# 區域提議方法 Region proposal methods
#  - 將分類器限制為 特定區域 specific region
#  - YOLO 通過預測邊界訪問整個圖像
#  - 通過附加的上下文，YOLO在背景區域中顯示出 更少的誤報
#
# YOLO 每個網格單元 檢測一個對象
#  - 在進行預測時，它會增強空間多樣性。
#
#  <img src="https://miro.medium.com/max/3210/1*XbOnbcZmc50hyhhTwhD5QA.png" width="75%">

# %% [markdown]
# ### Object Classification

# %% [markdown]
# Object Classification
#   - 對象分類 - 貓 - 狗 預測的分類
#   - CNN 已被證明是 圖像分類的 - 最佳架構之一
#
# <img src="https://cdn-images-1.medium.com/max/2400/1*R-ItxBW2SWarITBKe7HZuA.gif" width="50%">

# %% [markdown]
# ### Object Detection - 物體檢測

# %% [markdown]
# Object Detection - 物體檢測
# - 用於 檢測 數字圖像 和 視頻中特定類別的 語義對象
#         - 例如人 ，建築物 或 汽車
# - 對象檢測 在 Computer Vision 的 許多領域都有應用
#         - 包括 圖像檢索 和 視頻監視
#         - 最新技術，例如：
#             - YOLO - 移動目標檢測技術 on-the-go object detection techniqu
#                 - YOLO V1 - CNN 和 Anchor Boxes - 錨框 的簡潔體系結構 - 26層 架構
#                 - YOLO V2 - 準確性和速度方面都優於V1 - 30層  架構
#                 - YOLO V3 - 並不比V2快，但比V2更準確 - 106層 架構
#
#             - RetinaNet 視網膜網
#             - RCNN 神經網絡
#             - Fast-RCNN 快速RCNN
#             - Faster-RCNN 更快的RCNN
#             - Mask RCNN 遮罩RCNN
#
# <img src="https://nish1001.github.io/img/post-images/2019-04-18-object-detection-yolo/2.png" width="50%">

# %% [markdown]
# ## YOLO-v3 - Overall Architecture

# %% [markdown]
# <img src="https://nish1001.github.io/img/post-images/2019-04-18-object-detection-yolo/4.png" width="75%">

# %% [markdown]
# Yolo Detect System, 三個 - 重要的步驟 Step
# 1. Image Resize  - 448  X 448
# 2. 執行一個 CNN (GoogNet variant)
#   - YLOL CNN - CNN (24 layers) + FCN (2 layers)
#   - Diff YOLO vs GoogleNet
#     -  某些 3×3的 卷積層 前面 用   1×1的 卷積層 ==> 來減少 filter 數量
# 3. 基於模型輸出的 信心程度 - Confidence Level
#   - 依據 閾值 和 Non-Max Suppression, 獲到 - 偵測結果
#
# <img src="https://miro.medium.com/max/902/1*-n1T6yfcr5vlu-EgmibV9g.png" width="60%">

# %% [markdown]
# YOLO - 卷積網路架構
#   - 來自GoogleNet 的模型
#   - YOLO 的 網路
#         - 24層 卷積層  (convolutional layer)
#         -  2層 全連結層(fully connected layer)
#
# Note:
# - 1×1 CNN - 通常拿來做 降維度的作用，可以 減低計算量，且不影響太多 mAP
#
# **YOLO_v2**:
#
# <img src="https://miro.medium.com/max/1476/1*15YtCJxGoMJAr8JaoC8qCA.png" width="75%">

# %% [markdown]
# ## YOLO Object Detection - How?
#
#     - YOLO在物件偵測部分基本上 - 將圖拆成很多個 Grid Cell
#     - 每個 Grid Cell  進行 2個 Bounding Box
#             - 預測 屬於哪個 類別的 機率預測
#     - 最後用 - 閾值 Threshold
#              - NMS (Non-Maximum Suppression) 的方式- 得到結果

# %% [markdown]
# <img src="https://miro.medium.com/max/902/1*-n1T6yfcr5vlu-EgmibV9g.png" width="50%">
#
# YOLO - 如何得到很多個可能物件
#   * 信心程度 - Confidence Level
#   * 機率
#   * Bounding Boxes
#
# 假設輸入圖的大小是 100×100
# * 總共偵測 C個物件
# * YOLO 最後輸出的tensor的大小
#       - S × S × (B×5+C)
#
# Procedures:
# 1. YOLO 會把圖先平均分成 S×S 格.  (假設 S = 5):
#   - 圖會被平均分成 5×5格 － 如上左圖. 每一格稱為 - Grid ell － 大小為 20 × 20
#   - 被偵測的 物件中心落在哪一個 Grid Cell, 那個 Grid Cell－ 就要 負責偵測這個物件
#
# 2. 每個 Grid Gell
#   - 要負責預測「B 個 bounding boxes」和「屬於每個類別的機率」
#   - 每個 Bounding Box
#         - 帶有 5個預設值(x, y, w, h, and Confidence)
#         - (x, y)用來表示某一個物件在這個 Grid Cell的中心座標, 這個物件相對應的寬高 - 分別為 w, h
#         - Confidence: 表示這個物件是否為一個物件的 信心程度 (confidence score)

# %% [markdown]
# ## IoU - Intersection over Union

# %% [markdown]
# <img src="https://www.pyimagesearch.com/wp-content/uploads/2016/09/iou_stop_sign.jpg" width="40%">
# <img src="https://www.pyimagesearch.com/wp-content/uploads/2016/09/iou_equation.png" width="40%">
#
# <img src="https://miro.medium.com/max/579/1*iMcvqLGC7mCWFIZJTFlN2Q.png" width="40%">
#
# <img src="https://www.pyimagesearch.com/wp-content/uploads/2016/09/iou_examples.png" width="40%">

# %% [markdown]
# ## NMS - Non-Maximum Suppresion

# %% [markdown]
# * [Non-maximum Suppression (NMS)](https://medium.com/towards-data-science/non-maximum-suppression-nms-93ce178e177c)
# * [機器/深度學習: 物件偵測 Non-Maximum Suppression (NMS)](https://medium.com/@chih-sheng-huang821/%E6%A9%9F%E5%99%A8-%E6%B7%B1%E5%BA%A6%E5%AD%B8%E7%BF%92-%E7%89%A9%E4%BB%B6%E5%81%B5%E6%B8%AC-non-maximum-suppression-nms-aa70c45adffa)
#
# <img src="https://miro.medium.com/max/1050/1*OZwJcNsMZc7wT733fA_ITg.png" width="50%">
#
# * 這個選出來的框叫做Bounding Box/Boundary Box (也有人稱BBox)，每個BBox除了框的中心(x, y)和長寬(h, w)外，幾乎都會有一個**confidence score**。
# * 這個score代表的就是這個框是background還是foreground的信心程度，基本上介於0~1，白話說Score=1代表這個框可以肯定是一個物件，但這個物件是什麼類別要在看相對應的分類機率。
# * 所以一般每個BBox實際上帶有的資訊 (假設我們只偵測2個物件(貓和狗))，一般算法至少包含: BBox中心位置(x, y)、BBox長寬(h, w)、confidence score、BBox相對應是貓的機率和BBox相對應是狗的機率，共5+2=7。(如果演算法要做100類的偵測，那機率部分就會有100個輸出，那這個BBox總共會有5+100=105個輸出)。
#
# 一般文章會寫到NMS的演算法流程如下圖，坦白說很難懂
#
# <img src="https://miro.medium.com/max/867/1*xfn5ywPMbhkU9VQLiyHHXg.png" width="40%" align="right">
#
# NMS實際做法真的很簡單，這邊我會舉兩個例子說明，上面演算法參考就好了。
# 1. 第一個例子，有兩隻狗，我們怎麼用NMS將偵測到的物件框將把兩隻狗框出來。
# 2. 第二個例子，有1隻狗1隻貓，我們怎麼用NMS將偵測到的物件框將把貓和狗框出來。

# %% [markdown]
# ### Case 1: 有兩隻狗，我們怎麼用NMS將偵測到的物件框將把兩隻狗框出來

# %% [markdown]
# * 前面提到每個BBox會帶有BBox中心位置(x, y)、BBox長寬(h, w)、confidence score、BBox相對應是貓的機率和BBox相對應是狗的機率，但範例一我只看怎麼抓出狗，所以範例一我們只用到五個資訊
#   1. BBox中心位置(x, y)和BBox長寬(h, w): 這邊是算IoU用的。
#   2. confidence score。
#
#   - 這邊還要對IoU計算設定一個閾值(threshold)，也就是兩個框如果框太近(IoU值太大)，那就要刪掉一個框
# <img src="https://miro.medium.com/max/891/1*FzPoBiqN_PLrZsXh4wPhAw.png" width="40%">
#
# 所以步驟是
# 1. 先看哪個BBox的信心程度最高，那個BBox會進去「確定是物件集合」(途中的selected objects)內
# 2. 其他BBox和剛選出來的BBox算IoU，然後算出來的IoU大於設定好的閾值的BBox，那些BBox的信心度會被設定為0(也就是這個BBox重複計算要刪掉)。
#
# 然後在Repeat 1和2步驟直到所有的BBox都被處理完，這時候被存在「確定是物件集合」的物件就是最後結果。實際流程如下圖:
#
# <img src="https://miro.medium.com/max/1050/1*MnyRGTxCXPYl2q8dsaEqeQ.png" width="60%">

# %% [markdown]
# #### detailed steps

# %% [markdown]
# 1. 「確定是物件集合」= {空集合}
# 2. Run 1: 先將BBox依照信心程度排序，信心程度最高的BBox (紅色) 會被選入「確定是物件集合」內，其他BBox會看這步驟選出最高的BBox進行IoU計算，如果粉紅色的IoU為0.6大於我們設定的0.5，所以將粉紅色的BBox信心度設置為0。「確定是物件集合」= {紅色BBox }
# 3. Run 2: 不考慮信心度為0和已經在「確定是物件集合」的BBox，剩下來的物件繼續選出最大信心程度的BBox，將此BBox(黃色)丟入「確定是物件集合」，剩下的BBox和Run2選出的最大信心程度的BBox計算IoU，其他BBox都大於0.5，所以其他的BBox信心度設置為0。「確定是物件集合」= {紅色BBox; 黃色BBox}
# 4. 因為沒有物件信心度>0，所以結束NMS。
# 「確定是物件集合」= {紅色BBox; 黃色BBox}。

# %% [markdown]
# #### Can IoU threshold be larger than 0.5?

# %% [markdown]
# - 這邊衍生一個問題，為什麼IoU設定是0.5，不能在高一點嗎?
# - 剛剛的例子我這邊舉一個IoU閾值是0.7的例子(下圖)，看會發生什麼問題?
#
# <img src="https://miro.medium.com/max/1050/1*pn_5iAwhSzbNeqPc7pQGQQ.png" width="75%">
#
# - 由此可以知道，如果IoU閾值設定太高，可能會造成物件重複偵測的問題

# %% [markdown]
# ### Case 2: 有1隻狗1隻貓，我們怎麼用NMS將偵測到的物件框將把貓和狗框出來
# <img src="https://miro.medium.com/max/800/1*vDxtP2mTQ7kRRNjLq3ZUZA.png" width="30%">

# %% [markdown]
# 前面的範例一是標準的NMS程序，這邊要搭配一下分類來看，範例二和標準NSM作法一樣，先將「確定是物件集合」選出來，此例是NMS選出的BBox是{紫色BBox ; 紅色BBox}。
#
# 這時候在搭配一下分類的機率，就可以把每個NMS選出的BBox做類別判斷了(如下圖，每個BBox都會帶有一組機率)。
#
# <img src="https://miro.medium.com/max/1050/1*awPbUu3X7D5gGZSQIYSpKA.png" width="70%">

# %% [markdown]
# ### Notes on NMS

# %% [markdown]
# 這邊附上實際做法，還會先用一個閾值先初步去掉一些候選的BBox，不然假設一張圖預選出一萬個BBox，後面用CPU計算NMS會很花時間，所以會依據BBox的confidence score先去掉一些沒用的BBox，然後再做NMS，如下圖。
#
# <img src="https://miro.medium.com/max/1050/1*BriNRujosTSoOs8FgIagqA.png" width="60%">
#
# * 如果是two stage算法，通常在選出BBox只會帶有BBox中心位置(x, y)、BBox長寬(h, w)和confidence score，不會有類別的機率，因為程序是先選出BBox，在將選出BBox的feature map做rescale (一般用ROI pooling)，然後再用分類器分類。
# * 但如果是one stage作法，是直接BBox帶有BBox中心位置(x, y)、BBox長寬(h, w)和confidence score，以及相對應的分類機率，相對於two stage少了後面rescale和分類的程序，所以計算量相對小。
#
# * 因為如果two stage選出300個物件，後面ROI pooling只能用CPU算，很花時間的，NMS也只能用CPU算，所以one stage的做法是目前主流，要做到又快又好，計算量(參數量)和mAP兩個目前是trade offs，若能計算量小(參數量也小)，然後mAP 同時高，這就是演算法開發的目標，目前的關鍵是模型壓縮法，這部分論文方法超多(如: Pruning、Quantization、Low-rank factorization、Transferred/compact convolutional filters和Knowledge distillation，可以參考這篇文章
# [A Survey of Model Compression and Acceleration for Deep Neural Networks](https://arxiv.org/abs/1710.09282)

# %% [markdown]
# ## Confidence score

# %% [markdown]
# * 如果在某個 Grid Cell沒有任何物件
#   - 這時候confidence score 會是 0
# * 反之如果物件在 Grid Cells內, 最好的情況
#   - 就是 Confidence Score = 等於預測的 Bounding Box 和 Ground Truth 的 IOU
#   - IOU = (intersection over union)
# * 實際上 Confidence 預測
#   - 預測 Bounding Box 和 Ground Truth的 IOU - Intersection over Union
#   $$ Prob(Object) * {IOU}^{trutu}_{pred} $$
#
# * 每個 Grid Cells 還需要負責預測 -「屬於每個類別的機率」
#   - 所以每個 Grid Cells 還會有 - C 個條件機率(conditional class probabilities，
#
#   $${Prob(Class | Object)}$$
#
#   就知道這個條件機率 : 這個 Grid Cells 內 - 含有一個物件這個物件 屬於某一類的機率

# %% [markdown]
# ### class-specific confidence scores

# %% [markdown]
# 測試(Test)階段時:
# * 實際上, 每個 Bounding Box
#     - 會得到一組 class-specific confidence scores, 計算方式如下
#
#   $$
#   Pr(Class_i | Object) * Pr(Object) * IOU^{truth}_{pred} \\
#   = \frac{Pr(Class_i , Object)} {Pr(Object)} * Pr(Object) * IOU^{truth}_{pred} \\
#   = Pr(Class_i) * IOU^{truth}_{pred}
#   $$
#
# <img src="https://miro.medium.com/max/1500/1*_t-aKa0b3wNgAm01oKm8gg.png" width="50%">

# %% [markdown]
# ## YOLO's idea

# %% [markdown]
# ### on Bounding Box, NMS

# %% [markdown]
# YOLO作者的想法
# - 整張圖一共最多有 98個 Bounding Box, 實際最多只能偵測 98個 物件
# - 全部候選的 Bounding Box的 (中心座標、長寬, 和 confidence score)
#   - 根據閾值 Threshold 和 NMS, 選出這張圖所有的物件 (如下圖的紅色框、紫色框 和 土黃色框)
# - YOLO 作者的例子
#         - (7×7×(2×5+20))，共有7×7=49個 Grid Cells，
#         - 每個 Grid Cells 最多有2個Bounding box, 全部候選的 - Bounding Box - 7×7×2 = 98 個
#
#
# 98 個Bounding Box 的 Confidence Score
#   - 先經由一個 threshold (閾值), 先拿掉 一些確定不是物件的 Bounding Box, 可以減少後面 NMS (Non-maximal suppression) 的計算
#   - 然後再用 NMS 的方式 把一些重疊的 Bounding Box做一個消除
#     - 重覆執行直到 - 每個類別都完成
#   - 剩下來的 Bounding Boxs, 就是 選出來的物件
#
#
# **NMS Non-maximal suppression**
#   - YOLO 對同一物體進行 重複檢測, 為了解決這個問題
#     - YOLO應用 － NMS (非最大抑制以) 較低的置信度 刪除重複項
#   - 非最大抑制會在 mAP中增加 2-3％
#         － 這是可能的 非最大抑制實現之一
#         － 按置信度分數對預測進行排序
#         － 從最高分開始
#             － 如果我們發現任何先前的預測與當前預測具有相同的類並且 IoU> 0.5，則忽略任何當前預測
#             － 重複步驟，直到檢查完所有預測
#
# YOLO 同時間的輸出 － 還有( 7×7×20 )
#   - 這個代表每一個 Grid Cells內每一類的機率
#   - 這時候取機率最大的那一類
#   - 代表這個 Grid cell的類別 (下中圖)
#
# 這時候, 結合「步驟2選出的物件」和「步驟3對應的 Grid Cell是什麼類別可以決定這個選出的物件屬於什麼類別(下右圖)
#
# <img src="https://miro.medium.com/max/1949/1*8rCJUO5MSyAmFXTg_Cumag.png" width="˙50%">

# %% [markdown]
# ### on pre-trained model, BBox Normalization, Activation FN

# %% [markdown]
# * 用 ImageNet 1000-class competition dataset 來 pretrain 模型
#       - 只訓練前20卷積層
#       - 後面接上一個 average-pooling layer
#       - 一個 全連結層
#       - Top-5 accuracy = 88%
#
# * Bounding Box Normalization
#       - YOLO 的最後一層預測 - 類別機率 / Bounding Box . etc
#       - 在 YOLO 訓練前會先依據輸入圖的 長寬
#         - 正規化 (Normalize) Bounding Box 的長寬, 因此 Bounding Boxs的 長寬 - 介於 0~1 之間
#       - Bounding Boxs的 中心座標 (x,y), 是在 特定 Grid Cell的 偏移(offset) 座標 也 介於 0~1 之間
#
#
# * Activation function
#       - 整個 YOLO架構 除了最後一層用 線性輸出
#       - 每一層都會搭配 Leaky ReLU - leaky rectified linear activation
# <img src="https://miro.medium.com/max/882/1*JYZJbhklZIHxOnUv-FqAMA.png" width="50%">

# %% [markdown]
# ### on Loss FN

# %% [markdown]
# Loss function:
# 1. SSE (Sum-Squared Error SSE ) - Loss Function used in general literature
#   - 容易最佳化(可以參考 Back-propogation 相關文章)。
#   - 作者認為此方法 - 不能完美校正去最大化目標的平均精度(Aerage Precision)
#         - 主要原因
#             - 每項目的 Error( 如 Bounding Box的定位誤差(Localization Error) 和 分類的誤差(Class Error))都佔有一樣的比重
#             - 結果不太好
#                 - equal weight，(in every image many grid cells do not contain any object.)
#                 - 而且物件偵測多數情況, 大多數的 Grid Cells 內是沒有物件的
#                       － 梯度求解的時候容易將有物件的cell壓過去
#                       － 容易導致confidence幾乎趨近於 0, 因為如此容易造成模型不穩定
#
# 2. Proposal in YOLO
#   - 1. 增加了在bounding box座標預測的loss權重 (λcoord=5)
#   - 2. 減低那些不包含物件的 Box，Confidence預測時的權重(λnoobj=0.5)
#   - 3. Loss Function 只會針對物件 如果有出現在某個 Grid Cells 下進行懲罰分類錯誤
#     - 並且只會針對有責任於偵測 Ground truth box 的預測者 進行懲罰 Bounding Box錯誤 - 就是 Grid Cells中有最高 IoU 的 預測者
#
# 3. YOLO multi-part loss function定義如
#   - The final loss adds
#   - localization
#   - confidence
#   - classification losses together
#
# <img src="https://miro.medium.com/max/1038/1*Df3BdBxUjneUVeuMRGGC9Q.png" width="50%">

# %% [markdown]
# ## YOLO's Limitations

# %% [markdown]
# ## Ex - PASCAL VOC -YOLO (s=7, B=2, C=20)
# s=7, B=2, PASCAL VOC=20, So C=20

# %% [markdown]
# * YOLO 最後的 tensor 為 S×S×(B×5+C)
#   - PASCAL VOC 的例子, 輸出為 **7×7×(2×5+20)= 7×7×30**
#     - 7×7 個 Grid Cells，每一個 Grid Cells - 都會對應到原始圖的 相對位置
#     - 2×5 就是兩個 Bounding Box - 各自帶有 5 個數值,
#       - 分別為 Bounding Box的中心座標(x,y)和寬長(w, h)
#     - Confidence Score: 20 個 類別的 機率
#
# <img src="https://miro.medium.com/max/894/1*e833yrVnxM3GrJtQUM5SdA.png" width="60%">

# %% [markdown]
# Bounding Box 在每個 Grid Cell 怎麼看, 如下圖
# - 紅色點 為這個被偵測可能是物件的 中心點, 相對應的長寬可以框出紅色的框, 這個就是 Bounding box
# - 紅色點: 被偵測可能是物件的- 中心點
#     - 原因是 - 實際框出來的是狗的位置
#     - 但實際上 YOLO 的輸出- Bounding Box 在每個 - Grid Cell 是一定存在
#       - 有可能 Bounding Box框 - 是背景
# - YOLO 的每個 Bounding Box 都帶有一個 Confidence Score
#     - Confidence Score 可以來決定 Bounding Box 是否 - 真的是物件
# - 基本上 - 大多數的物件偵測都是這樣做
#
# <img src="https://miro.medium.com/max/2304/1*lxX75gUy_1kkiLerFsUcug.png" width="60%">

# %% [markdown]
# YOLO's Limitations
#   1. YOLO  - Bounding box 有很強烈的 空間限制
#     - 也就是每個 Grid Cell 只有 最多只有 2個 bounding box 和 一個類別
#       - 如果有 - 兩個以上的物件在空間上 , 離的非常近會導致 模型無法有 效偵測到(比如說有一群鳥(or 一群小物件))
#
#   2. Bounding Box 的預測 是從 - 資料學來的
#     - 如果訓練好的模型要去預測其他新物件, 或是比例很怪的物件, 可能就沒有辦法框的很好
#       - 部份原因: 來自於YOLO本身有很多層的 Pooling (downsampling)
#         - 最後得到的 Feature, 用來預測 Bounding Box
#         - 相較於原始圖 - 在空間上是比較粗略的
#
#   3. Loss Function 在小物件和大物件的 Bounding Box 都用一樣的比重
#       - 但實際上在計算 IOU 時,
#         - 小物件只要差一點點，定位(localization)的 error影響就會很大
#         - 相對的大物件而言就比較沒有太大差異
#       - 作者提到: 主要的錯誤, 都是來自不正確的定位(incorrect localizations)

# %% [markdown]
# ## YOLO v2

# %% [markdown]
# <img src="http://pjreddie.com/media/image/final.png" width="40%">
# <img src="https://miro.medium.com/max/1152/1*8Wy9b1i1YGSuV7A8W7NGcQ.png" width="50%">
#
# <img src="https://cdn-images-1.medium.com/max/1000/1*4YcPtqv9myJ1vypgb5wKnA.png" width="72%">
#
# <img src="https://nish1001.github.io/img/post-images/2019-04-18-object-detection-yolo/3.jpeg" width="72%">
#
# <img src="https://miro.medium.com/max/2384/1*JCqgJ2JDDyQeBA2IGKxlJQ.png" width="72%">

# %% [markdown]
# # YOLO example python implementation

# %% [markdown]
# ## Import the required libraries

# %%
# 忽略 Warning Messages - 訊息

import warnings
warnings.filterwarnings('ignore')

# %%
import os
import random
import numpy as np
import platform
import tensorflow
import keras
from tensorflow.keras import backend as K
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import plot_model

# %% [markdown]
# Directory Structure 目錄結構
#
#       - 02 - YOLO Algor introduction.ipynb
#       - yad2k.py
#       - yolo2.cfg
#       - yolo2.weights
#       - ├── font/
#       - │   ├── FiraMono-Medium.otf
#       - │   └── SIL Open Font License.txt
#       - │
#       - ├── images/
#       - │   └── dog.jpg
#       - ├── yad2k/
#       - │   ├── __init__.py
#       - │   ├── models/
#       - │   ├── utils/
#       - │   └── __pycache__/
#       - └── model_data/
#       -     ├── coco_classes.txt
#       -     ├── pascal_classes.txt
#       -     ├── yolov2_coco_608x608.h5
#       -     └── yolov2_coco_608x608_anchors.txt

# %%
import os
os.chdir("/content/")
# !git clone https://github.com/allanzelener/yad2k.git
os.chdir("./yad2k/")
# !ls -l
# Out:
# fatal: destination path 'yad2k' already exists and is not an empty directory.
# total 80
# -rw-r--r-- 1 root root  1099 Feb 22 06:34 environment.yml
# drwxr-xr-x 2 root root  4096 Feb 22 06:34 etc
# drwxr-xr-x 2 root root  4096 Feb 22 06:34 font
# drwxr-xr-x 2 root root  4096 Feb 22 06:34 images
# -rw-r--r-- 1 root root  1405 Feb 22 06:34 LICENSE
# drwxr-xr-x 2 root root  4096 Feb 22 06:34 model_data
# -rw-r--r-- 1 root root  3879 Feb 22 06:34 README.md
# -rw-r--r-- 1 root root 12524 Feb 22 06:34 retrain_yolo.py
# -rwxr-xr-x 1 root root  7274 Feb 22 06:34 test_yolo.py
# -rwxr-xr-x 1 root root  6889 Feb 22 06:34 train_overfit.py
# drwxr-xr-x 2 root root  4096 Feb 22 06:34 voc_conversion_scripts
# drwxr-xr-x 5 root root  4096 Feb 22 06:38 yad2k
# -rwxr-xr-x 1 root root 10596 Feb 22 06:34 yad2k.py

# %% [markdown]
# ## Determine the type of an image in Python
# imghdr - import imghdr

# %%
from PIL import Image, ImageDraw, ImageFont
import colorsys
import imghdr 
from yad2k.models.keras_yolo import yolo_eval, yolo_head
import cv2
from tqdm import tqdm
import time
import matplotlib
import matplotlib.pyplot as plt
import IPython.display as display
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-22-2b3049865429> in <module>()
#       2 import colorsys
#       3 import imghdr
# ----> 4 from yad2k.models.keras_yolo import yolo_eval, yolo_head
#       5 import cv2
#       6 from tqdm import tqdm
#
# /content/yad2k/yad2k/models/keras_yolo.py in <module>()
#      10
#      11 from ..utils import compose
# ---> 12 from .keras_darknet19 import (DarknetConv2D, DarknetConv2D_BN_Leaky,
#      13                               darknet_body)
#      14
#
# /content/yad2k/yad2k/models/keras_darknet19.py in <module>()
#       5 from keras.layers import Conv2D, MaxPooling2D
#       6 from keras.layers.advanced_activations import LeakyReLU
# ----> 7 from keras.layers.normalization import BatchNormalization
#       8 from keras.models import Model
#       9 from keras.regularizers import l2
#
# ...

# %%
# %matplotlib inline

print("Platform: {}".format(platform.platform()))
print("Tensorflow version: {}".format(tensorflow.__version__))
print("Keras version: {}".format(keras.__version__))
# Out:
# Platform: Windows-10-10.0.18362-SP0
# Tensorflow version: 1.14.0
# Keras version: 2.2.4

# %% [markdown]
# '''
#
# >> 設定相關 檔案的 - 目錄路徑
#
# '''

# %%
ddir

# %%
# 專案的根目錄路徑
ROOT_DIR = os.getcwd()

# 模型相關資料的目錄
MODEL_PATH = os.path.join(ROOT_DIR, "model_data")

# 圖像類別定義文件路徑，預設為"coco_classes.txt"
CLASSES_FILE_PATH = os.path.join(MODEL_PATH, "coco_classes.txt")

# 設定模型權重檔案
MODEL_FILENAME = "yolov2_coco_608x608.h5"

# 設定模型權重檔案路徑
MODEL_FILE_PATH = os.path.join(MODEL_PATH, MODEL_FILENAME)

# 設定錨點 - ANCHORS文件檔案
ANCHORS_FILENAME = "yolov2_coco_608x608_anchors.txt"

# 錨點 - ANCHORS 文件的路徑，預設為"yolo_anchors.txt" (x1,y1,x2,y2,x3,y3,x4,y4,x5,y5)
ANCHORS_FILE_PATH = os.path.join(MODEL_PATH, ANCHORS_FILENAME)

# 模型輸入的圖像大小與顏色頻道數
IMAGE_HEIGHT = 608
IMAGE_WEIGHT = 608
IMAGE_CHANNELS = 3

# 設定邊界框過濾的閥值 - Confidence Score  - Threshold
SCORE_THRESHOLD = 0.3

# IOU(Intersection Over Union)的 - 閥值 Threshold
IOU_THRESHOLD = 0.5

# 驗證用的圖像目錄，預設為 - images/  
TEST_PATH = os.path.join(ROOT_DIR, "images")

# 處理結果的圖像目錄，預設為 - images/out
OUTPUT_PATH = os.path.join(ROOT_DIR, "images_out")

# %%
# 檢查 - OUTPUT_PATH - 目錄 - 是否存在

if not os.path.exists(OUTPUT_PATH):
    print('Creating output path {}'.format(OUTPUT_PATH))
    os.mkdir(OUTPUT_PATH)

# %%
#  Tensorflow - session 物件

sess = K.get_session()

# %%
# 取得物件的 - 類別名稱(要看模型是用那一種資料集來進行訓練)

with open(CLASSES_FILE_PATH) as f:
    class_names = f.readlines() # 一行是一個圖像類別

# 把圖像類別放到一個列表中

class_names = [c.strip() for c in class_names]

# %%
# 取得- 圖像的預設錨點 (x1,y1,x2,y2,x3,y3,x4,y4,x5,y5)

with open(ANCHORS_FILE_PATH) as f:
    anchors = f.readline()
    anchors = [float(x) for x in anchors.split(',')]
    
    anchors = np.array(anchors).reshape(-1, 2) # 錨點是 (x, y) 一組

# %% [raw]
# '''
#
# >> 載入網絡結構模型
#
#
# '''

# %%
# 載入由 Darknet轉換 - YOLOv2 模型

yolo_model = load_model(MODEL_FILE_PATH)

# %%
# 列印 - 模型結構

yolo_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 608, 608, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 608, 608, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 608, 608, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 608, 608, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 304, 304, 32) 0           leaky_re_lu_1[0][0]
# ...

# %% [markdown]
# import pydot
# from keras.utils import plot_model

# %% [raw]
# from keras.utils import plot_model
# from IPython.display import Image
#
# # 產生網絡拓撲圖
# plot_model(yolo_model, to_file='yolov2_graph.png')
# display.Image('yolo2_model.png')

# %%
num_classes = len(class_names) # "coco" -> 80, "pacal" -> 20
num_anchors = len(anchors) # 錨點 Anchors - 個數

# 取出 YOLOv2模型 的最後一層 -> "conv2d_23"的輸出為 (19, 19, 425)

model_output_channels = yolo_model.layers[-1].output_shape[-1] 

# 最後的features map的維度是19x19x425 (為什麼是425)
# 主要是因為YOLOv2把整個圖像分成19x19個小區塊(cell)
# 而每個小區塊(cell)要predict"num_anchors(5)"個邊界框(bounding boxes)
# 因此(19, 19, 425)中的前2個維度就是定義每一個小區塊(cell), 而"425"則代表著:
#     - x, y, width, height (定義邊界框的座標) -> 4個浮點數
#     - 邊界框裡包含物體的信心分數(confidence score) -> 1個浮點數
#     - 每一種類別的機率(num_classes) -> 80個浮點數 (MS Coco的資料集有80種圖像類別)


# 驗證 model, anchors, 與 classes 是相符合的

if model_output_channels != (num_anchors * (num_classes + 5)):
    print('Mismatch between model and given anchor and class sizes.')
    
print('model[{}] , anchors[{}], and classes[{}] loaded.'.format(MODEL_FILENAME, num_anchors, num_classes))
# Out:
# model[yolov2_coco_608x608.h5] , anchors[5], and classes[80] loaded.

# %%
# 檢查模型  -Input 圖像大小

model_image_size = yolo_model.layers[0].input_shape[1:3] # (h, w, channel)

is_fixed_size = model_image_size != (None, None) # 如果 h, w都是"None"代表任何圖像的size都可以
print("Flag: is_fixed_size [{}]".format(is_fixed_size))

print("Model input image size: ", model_image_size) # 列印 出來
# Out:
# Flag: is_fixed_size [True]
# Model input image size:  (608, 608)

# %%
# 為不同的 Bounding Boxes - 產生不同的顏色

hsv_tuples = [(x / len(class_names), 1., 1.) for x in range(len(class_names))]

colors = list(map(lambda x: colorsys.hsv_to_rgb(*x), hsv_tuples))
colors = list(map(lambda x: (int(x[0] * 255), int(x[1] * 255), int(x[2] * 255)), colors))

random.seed(10101)      # 設定random的seed讓整個運行中的顏色有一致性。
random.shuffle(colors)  # 打散顏色
random.seed(None)       # 回複到預設值

# %%
# 最後的圖層特徵 - 轉換為 邊框 - 的相對參數

yolo_outputs = yolo_head(yolo_model.output, anchors, len(class_names))

input_image_shape = K.placeholder(shape=(2, ))

# YOLO模型 評估 給定的輸入批次和相關的閥值, 返回過濾後的邊界框

boxes, scores, classes = yolo_eval(yolo_outputs,
                                  input_image_shape,
                                  score_threshold=SCORE_THRESHOLD,
                                  iou_threshold=IOU_THRESHOLD)
# Out:
# W1024 11:16:48.442822 12356 deprecation.py:323] From C:\Users\calvi\Anaconda3\lib\site-packages\tensorflow\python\ops\array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [raw]
# 圖像的物體偵測
#   - 先看一下原始的要用來測試的圖像

# %%
# TEST_IMG = "horses.jpg" # <----- 你可以替換其它不同的圖像
# TEST_IMG = "person.jpg" # <----- 你可以替換其它不同的圖像


# 指定要用來進行物體偵測的圖像
TEST_IMG = "dog.jpg" # <----- 可以替換其它不同的圖像

# 驗證用的圖像目錄，預設為"images/"

TEST_IMG_PATH = os.path.join(TEST_PATH, TEST_IMG)

# %%
#  原始的圖像 列印出來

plt.figure(figsize=(15,8)) # 設定- 圖像的大小
img=plt.imread(TEST_IMG_PATH) # 讀入圖像
plt.imshow(img) # 列印

# %% [markdown]
# '''
#
# >> YOLOv2 - 偵測物體
#
# >> YOLO的模型
#     >> 主要的任務有兩個:
#         - 1. 偵測邊界框 - Bounding boxes
#         - 2. 對邊界框裡的物體進行辨識 - Object recognition
#
# >> Darknet 用 - MS COCO圖像集 - 預訓練的 YOLOv2 608x608 模型
#     >> 預訓練的模型 - 預期的圖像輸人前處理:
#
#     - 1. 圖像資料的張量形狀(tensor shape)為(608, 608, 3)
#         - 是圖像RGB三色頻且大小為608x608
#     - 2. 圖像的張量需要進行歸一化的處理(除以255)以及資料型別為浮點數32
#
# '''

# %% [markdown]
# ### 資料前處理

# %%
# 載入圖像

image = Image.open(TEST_IMG_PATH)

print("Before image resize: ", np.array(image, dtype='float32').shape)

# 修改輸入圖像大小來符合模型的要求

resized_iamge = image.resize(tuple(reversed(model_image_size)), Image.BICUBIC)
image_data = np.array(resized_iamge, dtype='float32') # (img_height, img_width, img_channels)

print("After image resize: ", image_data.shape)
    
# 進行圖像歸一處理 - Normalization

image_data /= 255.

# 增加"批次 Batch "的維度

print("Before expand dims:",image_data.shape) # (img_height, img_width, img_channels)

image_data = np.expand_dims(image_data, 0) # 增加 batch dimension

print("After expand dims:",image_data.shape) # (sample_size, img_height, img_width, img_channels)
# Out:
# Before image resize:  (576, 768, 3)
# After image resize:  (608, 608, 3)
# Before expand dims: (608, 608, 3)
# After expand dims: (1, 608, 608, 3)

# %% [markdown]
# '''
#
# >> 資料的推論預測
#
#     - YAD2K的YOLO - 結合了 Keras 與 Tensorflow,
#         - 在預測的階段
#             - 需要使用 Tensorflow - Session物件
#
# >> 一個圖像中可能有多個邊界框
#     - 因此在YOLO的模型在進行圖像的輸入之後會有以下的輸出:
#
#         - 1. 邊界框列表(boxes)
#             -列表中的每個資料結構包括了4個浮點數, 分別代表左上角的(x1,y1)及右下角的(x2,y2)
#         - 2. 邊界框信心分數列表(confidence scores)
#             -列表中的每個資料結構包括了1個浮點數, 代表每個邊界框有物體在框內的信心分數
#         - 3. 邊界框物體類別機率列表(object category probabilities)-列表中的每個資料結構包括了1個整數
#             - 代表機率值最大的那一個物體類別的索引
#
# '''

# %%
# YOLOv2 Model 模型 - 偵測 的結果


out_boxes, out_scores, out_classes = sess.run([boxes, scores, classes],
                                             feed_dict={
                                                 yolo_model.input: image_data,
                                                 input_image_shape: [image.size[1], image.size[0]],
                                                 K.learning_phase(): 0
                                             })

print("out_boxes.shape:", out_boxes.shape, out_boxes.dtype)
print("out_scores.shape:", out_scores.shape, out_scores.dtype)
print("out_classes.shape:", out_classes.shape, out_classes.dtype)
# Out:
# out_boxes.shape: (3, 4) float32
# out_scores.shape: (3,) float32
# out_classes.shape: (3,) int64

# %%
# 列印 找到個 - Bounding Boxes  

print('Found {} boxes for {}'.format(len(out_boxes),TEST_IMG))

# 列印每個找到 - 物體類別、信心分數與 - 邊框 - 左上角 與 右下角座標

for i, c in reversed(list(enumerate(out_classes))):
    predicted_class = class_names[c]
    box = out_boxes[i]
    score = out_scores[i]
    
    top, left, bottom, right = box
    top = max(0, np.floor(top + 0.5).astype('int32'))                   # 避免左上角座標超出原始圖像的左上角(0,0)
    left = max(0, np.floor(left + 0.5).astype('int32'))                 # 避免左上角座標超出原始圖像的左上角(0,0)
    bottom = min(image.size[1], np.floor(bottom + 0.5).astype('int32')) # 避免右下角座標超出原始圖像的右下角(608,608)
    right = min(image.size[0], np.floor(right + 0.5).astype('int32'))   # 避免右下角座標超出原始圖像的右下角(608,608)
    
    label = '{} {:.2f} [({}, {}),({}, {})]'.format(predicted_class, score, top, left, bottom, right)
    print(label)
# Out:
# Found 3 boxes for dog.jpg
# dog 0.78 [(214, 137),(540, 323)]
# truck 0.80 [(82, 462),(168, 694)]
# bicycle 0.84 [(112, 81),(469, 554)]

# %% [markdown]
# '''
#
# >>圖像 偵測 - 的結果
#
#     >> 圖像上 - 繪製 物體類別、信心分數 與 邊框
#
# '''

# %%
#  設定字型 - font/FiraMono-Medium.otf  - Option - font/SIL Open Font License.txt

font = ImageFont.truetype(font='font/FiraMono-Medium.otf',
                         size=np.floor(3e-2 * image.size[1]+0.5).astype('int32'))

# 設定邊框 - 厚度

thickness = (image.size[0]+image.size[1]) // 300

# 迭代 - 每個找到的 - 物體類別
for i, c in reversed(list(enumerate(out_classes))):
    predicted_class = class_names[c]
    box = out_boxes[i]
    score = out_scores[i]

    label = '{} {:.2f}'.format(predicted_class, score)

    draw = ImageDraw.Draw(image) # 使用 Draw  - 圖像上 - 畫圖
    
    label_size = draw.textsize(label, font) #  物體類別 -  信心分數 - 以文字 表現
    
    #  - 邊框 -  座標
    
    top, left, bottom, right = box
    top = max(0, np.floor(top + 0.5).astype('int32'))
    left = max(0, np.floor(left + 0.5).astype('int32'))
    bottom = min(image.size[1], np.floor(bottom + 0.5).astype('int32'))
    right = min(image.size[0], np.floor(right + 0.5).astype('int32'))

    # 列印 - 圖像類別, 邊界框 的 - 左上角 - 右下角 --- 座標
    
    print(label, (left, top), (right, bottom))

    if top - label_size[1] >= 0:
        text_origin = np.array([left, top - label_size[1]])
    else:
        text_origin = np.array([left, top + 1])

    
    for i in range(thickness):
        # 畫  - 邊框 
        draw.rectangle(
            [left + i, top + i, right - i, bottom - i],
            outline=colors[c])
    
    # 畫一個-  四方型 -  做 - 文字標籤的背景
    draw.rectangle(
        [tuple(text_origin), tuple(text_origin + label_size)],
        fill=colors[c])
    
    #  文字標籤的資訊 - 到圖像上
    draw.text(text_origin, label, fill=(0, 0, 0), font=font)
    
    del draw # 移除 - draw 物件

# 將- 最後的圖像 - 畫出來

plt.figure(figsize=(15,8)) # 設定 - 列印圖像大小
plt.imshow(image) # 展示

# 儲存處理過的圖像  - Option 
# image.save(os.path.join(OUTPUT_PATH, image_file), quality=90)
# Out:
# dog 0.78 (137, 214) (323, 540)
# truck 0.80 (462, 82) (694, 168)
# bicycle 0.84 (81, 112) (554, 469)

# %%
# 關閉 Close it U p  - Tensorflow  - Session 

sess.close()

# %% [markdown]
# # Reference

# %% [markdown]
#     >> 論文的網頁 - 鏈接 https://pjreddie.com/media/files/papers/YOLOv3.pdf. # YOLOv1/YOLOv2
#
# >>
#
#     >> 你我互動學習園地- 進階課程 Advanced Course
#         >> https://interactiveuandmetutorialsac.weebly.com/
#
#     >> 你我互動學習園地
#         >> https://interactiveuandmetutorials.weebly.com/
#
#     >> Python 程式語言 設計
#         >> https://pythonprogrammingtutorials.weebly.com/
#
#
# >>
#
#     >> YOLO官網
#         >> https://pjreddie.com/darknet/yolo/
#
#     >> YOLO_Object_Detection
#         >> https://github.com/llSourcell/YOLO_Object_Detection
#
#     >> allanzelener/YAD2K
#         >> https://github.com/allanzelener/YAD2K
