# %% [markdown]
# # Deep Reinforcement Learning <em> in Action </em>
# ## Ch 1. Introduction
# ### Dynamic Programming

# %%
def fib(n):
    if n <= 1:
        return n
    else:
        return fib(n - 1) + fib(n - 2)

# %%
fib(7)
# Out:
# 13

# %%
mem = {0:0, 1:1}
def fib_mem(n):
    if n not in mem:
        mem[n] = fib(n - 1) + fib(n - 2)
    return mem[n]

mem8 = {0:0, 1:1, 2:1, 3:2, 4:3, 5:5, 6:8, 7:13, 8:21}
def fib_mem8(n):
    if n not in mem8:
        mem8[n] = fib(n - 1) + fib(n - 2)
    return mem8[n]

# %%
fib_mem(7)
# Out:
# 13

# %% [markdown]
# ### Time Performance

# %%
n=35

# %%
# %timeit fib(n)
# We get 5.54 seconds to run with n=35

# %%
# %timeit fib_mem(n)
# 1st run - We get 906 ns to run with n=35

# %timeit fib_mem(n)
# 2nd run - We get 161 ns to run with n=35

# %%
# %timeit fib_mem8(n)
# 1st run - We get 563 ns to run with n=35

# %timeit fib_mem8(n)
# 2nd run - We get 176 ns to run with n=35
